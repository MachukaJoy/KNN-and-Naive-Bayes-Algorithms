# %% [markdown]
# <a href="https://colab.research.google.com/github/MachukaJoy/KNN-and-Naive-Bayes-Algorithms/blob/main/Dataset2NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# Build a model that predicts whether an email is spam or not.

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# Our model will be considered a success if we are able to measure its' performance and obtain an acceptable accuracy score and optimize it to increase the various measures of performance such as accuracy.

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# The "spam" concept is diverse: advertisements for products/websites, make money fast schemes, chain letters, pornography...
# Our collection of spam e-mails came from our postmaster and
# individuals who had filed spam. Our collection of non-spam
# e-mails came from filed work and personal e-mails, and hence
# the word 'george' and the area code '650' are indicators of
# non-spam.A dataset of various collected emails by individuals. The individuals marked the mails received as either spam or not with a few characteristics.

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# * Defining the question
# * Data Preparation
# * Data Cleaning
# * Univariate Analysis
# * Bivariate Analysis
# * Modelliing
# * Optimization
# * Challenging the solution
# * Conclusion

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# ## 2. Reading the Data

# %%
#importing needed libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, mean_squared_error, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the Data from the source i.e. csv
# ---

# Dataset 2 Source: https://archive.ics.uci.edu/ml/datasets/Spambase
#
dfspam = pd.read_csv('/content/spambase.data',header=None)
dfspam
# Out:
#         0     1     2    3     4     5   ...     52     53     54   55    56  57
# 0     0.00  0.64  0.64  0.0  0.32  0.00  ...  0.000  0.000  3.756   61   278   1
# 1     0.21  0.28  0.50  0.0  0.14  0.28  ...  0.180  0.048  5.114  101  1028   1
# 2     0.06  0.00  0.71  0.0  1.23  0.19  ...  0.184  0.010  9.821  485  2259   1
# 3     0.00  0.00  0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191   1
# 4     0.00  0.00  0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191   1
# ...    ...   ...   ...  ...   ...   ...  ...    ...    ...    ...  ...   ...  ..
# 4596  0.31  0.00  0.62  0.0  0.00  0.31  ...  0.000  0.000  1.142    3    88   0
# 4597  0.00  0.00  0.00  0.0  0.00  0.00  ...  0.000  0.000  1.555    4    14   0
# 4598  0.30  0.00  0.30  0.0  0.00  0.00  ...  0.000  0.000  1.404    6   118   0
# 4599  0.96  0.00  0.00  0.0  0.32  0.00  ...  0.000  0.000  1.147    5    78   0
# 4600  0.00  0.00  0.65  0.0  0.00  0.00  ...  0.000  0.000  1.250    5    40   0
#
# ...

# %%
columnnames = ['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d', 'word_freq_our',
'word_freq_over', 'word_freq_remove', 'word_freq_internet', 'word_freq_order', 'word_freq_mail',
'word_freq_receive','word_freq_will','word_freq_people','word_freq_report','word_freq_addresses',
'word_freq_free','word_freq_business','word_freq_email','word_freq_you','word_freq_credit','word_freq_your',
'word_freq_font','word_freq_000','word_freq_money','word_freq_hp','word_freq_hpl','word_freq_george',
'word_freq_650','word_freq_lab','word_freq_labs','word_freq_telnet','word_freq_857','word_freq_data',
'word_freq_415','word_freq_85','word_freq_technology','word_freq_1999','word_freq_parts','word_freq_pm',
'word_freq_direct','word_freq_cs','word_freq_meeting','word_freq_original','word_freq_project',
'word_freq_re','word_freq_edu','word_freq_table','word_freq_conference','char_freq_;','char_freq_(',
'char_freq_[','char_freq_!','char_freq_$','char_freq_#','capital_run_length_average',
'capital_run_length_longest','capital_run_length_total','spam']

# %%
dfspam = pd.read_csv('/content/spambase.data',names=columnnames)

# %% [markdown]
# ## 3. Checking the Data

# %%
# Determining the no. of records in our dataset
#
dfspam.shape
# Out:
# (4601, 58)

# %%
# Previewing the top of our dataset
dfspam.head()
# Out:
#    word_freq_make  word_freq_address  ...  capital_run_length_total  spam
# 0            0.00               0.64  ...                       278     1
# 1            0.21               0.28  ...                      1028     1
# 2            0.06               0.00  ...                      2259     1
# 3            0.00               0.00  ...                       191     1
# 4            0.00               0.00  ...                       191     1
#
# [5 rows x 58 columns]

# %%
# Previewing the bottom of our dataset
# 
dfspam.tail()
# Out:
#       word_freq_make  word_freq_address  ...  capital_run_length_total  spam
# 4596            0.31                0.0  ...                        88     0
# 4597            0.00                0.0  ...                        14     0
# 4598            0.30                0.0  ...                       118     0
# 4599            0.96                0.0  ...                        78     0
# 4600            0.00                0.0  ...                        40     0
#
# [5 rows x 58 columns]

# %%
# Checking whether each column has an appropriate datatype
#
dfspam.dtypes
# Out:
# word_freq_make                float64
# word_freq_address             float64
# word_freq_all                 float64
# word_freq_3d                  float64
# word_freq_our                 float64
# word_freq_over                float64
# word_freq_remove              float64
# word_freq_internet            float64
# word_freq_order               float64
# word_freq_mail                float64
# word_freq_receive             float64
# word_freq_will                float64
# word_freq_people              float64
# word_freq_report              float64
# word_freq_addresses           float64
# word_freq_free                float64
# word_freq_business            float64
# word_freq_email               float64
# word_freq_you                 float64
# word_freq_credit              float64
# word_freq_your                float64
# word_freq_font                float64
# word_freq_000                 float64
# word_freq_money               float64
# word_freq_hp                  float64
# ...

# %%
#getting information about our dataset
dfspam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %% [markdown]
# ## 5. Tidying the Dataset

# %%
#checking column names naming system
dfspam.columns

# Okay since we named the columns ourselves
# Out:
# Index(['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d',
#        'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
# ...

# %%
#checking for duplicates
dfspam.duplicated().sum()
# Out:
# 391

# %%
dfspam.shape
# Out:
# (4601, 58)

# %% [markdown]
# Our dataset is quite large so we drop duplicates.

# %%
#dropping duplicates
dfspam.drop_duplicates(inplace =True)
dfspam.shape
# Out:
# (4210, 58)

# %%
#checking for null values
dfspam.isnull().sum()
# Out:
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_freq_our                 0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# word_freq_lab                 0
# ...

# %% [markdown]
# There aren't any nulls.

# %%
# Checking for Anomalies
#
# for col in dfspam.columns.to_list():
#   print(f'{col} column unique values: ')
#   print(dfspam[col].unique(), end='\n\n')

# %%
# Checking for Outliers
#
# fig, ax = plt.subplots(len(dfspam.columns), figsize= (200,200)

# for i, col_val in enumerate(dfspam.columns):
#   sns.boxplot(dfspam[col_val], ax= ax[i])
#   ax[i].set_title('Box plot - {}'.format(col_val), fontsize= 10)
#   ax[i].set_xlabel(col_val, fontsize= 8)
# plt.show()

# %%
q3 = dfspam.quantile(0.75)
q1 = dfspam.quantile(0.25)

iqr = q3-q1
# iqr

# %% [markdown]
# We decided not to remove outliers.

# %%
dfspam.shape
# Out:
# (4210, 58)

# %% [markdown]
# ## Univariate analysis

# %%
# Statistical analysis
dfspam.describe()
# Out:
#        word_freq_make  word_freq_address  ...  capital_run_length_total         spam
# count     4210.000000        4210.000000  ...               4210.000000  4210.000000
# mean         0.104366           0.112656  ...                291.181948     0.398812
# std          0.300005           0.454260  ...                618.654838     0.489712
# min          0.000000           0.000000  ...                  1.000000     0.000000
# 25%          0.000000           0.000000  ...                 40.000000     0.000000
# 50%          0.000000           0.000000  ...                101.500000     0.000000
# 75%          0.000000           0.000000  ...                273.750000     1.000000
# max          4.540000          14.280000  ...              15841.000000     1.000000
#
# [8 rows x 58 columns]

# %%
#Spam distribution
plt.figure(figsize=(15, 4))
sns.countplot(dfspam['spam'], order = dfspam['spam'].value_counts().index);
plt.title('Spam distribution')
# Out:
# Text(0.5, 1.0, 'Spam distribution')

# %% [markdown]
# Most mails were not spam

# %%
fig, axes = plt.subplots(nrows=10, ncols=5, figsize = (15,30))
fig.subplots_adjust(hspace=0.5)
fig.suptitle('Distributions of vrious features')

for ax, values, name in zip(axes.flatten(), dfspam.values.T, dfspam.columns):
    sns.distplot(values, ax=ax, bins=len(np.unique(dfspam.values.T[1]))//2)
    ax.set(title="Dist of {}".format(name), xlabel=name)

# %% [markdown]
# Most variables seem normally distributed

# %% [markdown]
# ## Bivariate analysis

# %%
#plotting a pairplot to show correlation and distribution and use the hue parameter 'spam' as its 
# the categorical variable we are trying to predict
# sns.pairplot(dfspam)
# plt.show()

# %%
# plotting heatmap
corr = dfspam.corr() 
plt.figure(figsize = (20,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
plt.title('Heatmap for Correlation ')
plt.show()

# %%
#plot correlation table since our heatmap is barely visible
corr = dfspam.corr() 
corr
# Out:
#                             word_freq_make  ...      spam
# word_freq_make                    1.000000  ...  0.129194
# word_freq_address                 0.034012  ...  0.100651
# word_freq_all                     0.063207  ...  0.172350
# word_freq_3d                      0.005388  ...  0.056383
# word_freq_our                     0.021740  ...  0.230074
# word_freq_over                    0.055067  ...  0.212311
# word_freq_remove                  0.011061  ...  0.334456
# word_freq_internet               -0.004370  ...  0.200666
# word_freq_order                   0.103842  ...  0.221454
# word_freq_mail                    0.040829  ...  0.131686
# word_freq_receive                 0.063031  ...  0.272451
# word_freq_will                    0.075911  ... -0.014606
# word_freq_people                  0.061985  ...  0.118024
# word_freq_report                  0.032263  ...  0.053534
# word_freq_addresses               0.022454  ...  0.183849
# ...

# %% [markdown]
# ## Modelling

# %% [markdown]
# We will start with gaussian naive bayes classifier as we assume normal distribution from our distplots also our dataset has continuous variables

# %% [markdown]
# ### Gaussian Naive Bayes Classifier

# %% [markdown]
# #### 80/20 Split

# %%
#import gaussian library
from sklearn.naive_bayes import GaussianNB

#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Training our model
# 
clf = GaussianNB()  
model = clf.fit(X_train, y_train) 

#  Predicting our test predictors
y_pred = model.predict(X_test)
print(np.mean(y_pred == y_test))

#Evaluate the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.8206650831353919
# [[357 138]
#  [ 13 334]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.72      0.83       495
#            1       0.71      0.96      0.82       347
#
#     accuracy                           0.82       842
#    macro avg       0.84      0.84      0.82       842
# weighted avg       0.86      0.82      0.82       842

# %% [markdown]
# #### 70/30 Split

# %%
#import gaussian library
from sklearn.naive_bayes import GaussianNB

#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Training our model
# 
clf = GaussianNB()  
model = clf.fit(X_train, y_train) 

#  Predicting our test predictors
y_pred = model.predict(X_test)
print(np.mean(y_pred == y_test))

#Evaluate the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.833729216152019
# [[541 196]
#  [ 14 512]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.84       737
#            1       0.72      0.97      0.83       526
#
#     accuracy                           0.83      1263
#    macro avg       0.85      0.85      0.83      1263
# weighted avg       0.87      0.83      0.83      1263

# %% [markdown]
# #### 60/40 Split

# %%
#import gaussian library
from sklearn.naive_bayes import GaussianNB

#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# Training our model
# 
clf = GaussianNB()  
model = clf.fit(X_train, y_train) 

#  Predicting our test predictors
y_pred = model.predict(X_test)
print(np.mean(y_pred == y_test))

#Evaluate the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.8319477434679335
# [[735 259]
#  [ 24 666]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84       994
#            1       0.72      0.97      0.82       690
#
#     accuracy                           0.83      1684
#    macro avg       0.84      0.85      0.83      1684
# weighted avg       0.87      0.83      0.83      1684

# %% [markdown]
# The 70/30 has a slightly better performance by evaluation compatre to the 60/40 split. We therefore optimize the 70/30 split model.

# %% [markdown]
# Below we were trying the multinomial naive bayes although the assumption made(discrete data) is strongly against the nature of the datset(continuous)

# %%
#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Training our model
# Trying multinomial naive bayes
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB().fit(X_train, y_train)

# Evaluating the Model
# Once we have put together our classifier, we can evaluate its performance in the testing set
# 
predicted = model.predict(X_test)
print(np.mean(predicted == y_test))
# Out:
# 0.782264449722882

# %% [markdown]
# Mean score is also lower than the gaussian model we therefoe stick to gaussian model as decided initially.

# %% [markdown]
# ### Optimizing by LDA

# %%
#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

#standard scaler for feature scalin
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Peforming LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=40)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# Training our model
# 
clf = GaussianNB()  
model = clf.fit(X_train, y_train) 

#  Predicting our test predictors
y_pred = model.predict(X_test)
print(np.mean(y_pred == y_test))

#Evaluate the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.8990498812351544
# [[933  61]
#  [109 581]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       994
#            1       0.90      0.84      0.87       690
#
#     accuracy                           0.90      1684
#    macro avg       0.90      0.89      0.89      1684
# weighted avg       0.90      0.90      0.90      1684

# %% [markdown]
# ### Optimizing by removing highly correlated vaiables

# %%
#splitting
X = dfspam.drop('spam', axis=1)
y = dfspam['spam']

correlations = X.corr()
correlations
pd.DataFrame(np.linalg.inv(correlations.values), index = correlations.index, columns=correlations.columns)
# Out:
#                             word_freq_make  ...  capital_run_length_total
# word_freq_make                    1.101307  ...                 -0.038375
# word_freq_address                -0.004149  ...                 -0.005508
# word_freq_all                    -0.015513  ...                 -0.007165
# word_freq_3d                     -0.000943  ...                 -0.010699
# word_freq_our                     0.009130  ...                  0.036212
# word_freq_over                   -0.012852  ...                  0.007355
# word_freq_remove                  0.035940  ...                  0.085004
# word_freq_internet                0.049783  ...                  0.013031
# word_freq_order                  -0.061157  ...                 -0.182183
# word_freq_mail                   -0.005142  ...                 -0.007861
# word_freq_receive                -0.002407  ...                 -0.086625
# word_freq_will                   -0.069767  ...                  0.015038
# ...

# %% [markdown]
# Our VIF scores barely show high collinearity amongst variables. (none above even 4) We therefore did not perform any reduction by collinearity.

# %% [markdown]
# ## Challenging the solution

# %% [markdown]
# Our 70/30 split model performed the best initially with 83% score. After optimizing by performing LDA, we got a better accuracy of 90%. We therefore recommend the 70/30 split with LDA.
